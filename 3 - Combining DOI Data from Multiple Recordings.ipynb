# %%
#Add folders containing data you want to use

## DOI - All Mice used for pre post doi freelymoving 
RecordingsToUse = [r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\091223\G6CK9GRT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\092223\G6CK9GTT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\110723\J683LT',
                  r'\\goeppert\Vol2\Rolf\Freely Moving Ephys\2024\022024\G6CK10DTT',
                  r'D:\072624\J708LT',
                  r'D:\080224\J705RT',
                  r'D:\081024\J720LT',
                  #r'H:\101724\G6CK10JRT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT']


RecordingsToUse = [r'F:\Science\Freely Moving Ephys\DOI Mice\101724\G6CK10JRT',
                   r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2025\022725\G6CK14BTT',
                   r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2025\060625\J748RT',
                   r'I:\111524\J715RT']

print(len(RecordingsToUse))

# %%
#12 mice with 4 pre post dark/light data
RecordingsToUse = [r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\091223\G6CK9GRT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\092223\G6CK9GTT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\110723\J683LT',
                  r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2024\022024\G6CK10DTT',
                  r'D:\072624\J708LT',
                  r'D:\080224\J705RT',
                  r'D:\081024\J720LT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT']

# %%
#Pre/Post Light/Dark
RecordingsToUse = [r'F:\Science\Freely Moving Ephys\DOI Mice\101724\G6CK10JRT',
                  r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2025\022725\G6CK14BTT',
                  r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2025\060625\J748RT',
                  r'I:\111524\J715RT']

# %%
#Use this for creating a dataset to compare to drifting grating data

RecordingsToUse = [r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\110723\J683LT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\012324\G6CK11BTT',
                  r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2024\022024\G6CK10DTT',
                  r'D:\072624\J708LT',
                  r'D:\080224\J705RT',
                  r'D:\081024\J720LT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT',
                  r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2025\013125\G6CK14BLN',
                  r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2025\021225']

print(len(RecordingsToUse))

# %%
#Use this for creating a dataset to compare to sparse noise stimuli
RecordingsToUse = [r'D:\072624\J708LT',
                  r'D:\080224\J705RT',
                  r'D:\081024\J720LT',
                   r'H:\101724\G6CK10JRT',
                   r'H:\102624\J722LT',
                   r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT',
                   r'\\goeppert\Vol2\Rolf\Freely Moving Ephys\2025\013125\G6CK14BLN']



print(len(RecordingsToUse))

# %%
RecordingsToUse = [r'D:\072624\J708LT',
                  r'D:\080224\J705RT',
                  r'D:\081024\J720LT',
                   r'H:\101724\G6CK10JRT',
                   r'H:\102624\J722LT',
                   r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT',
                   r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2025\013125\G6CK14BLN']

# %%
#Use this for creating a dataset to compare to Reverse Checkerboard stimuli
RecordingsToUse = [r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\110723\J683LT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\012324\G6CK11BTT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\022024\G6CK10DTT',
                  r'D:\072624\J708LT',
                  r'D:\080224\J705RT',
                  r'D:\081024\J720LT',
                  r'H:\101724\G6CK10JRT',
                  r'H:\102624\J722LT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT']

print(len(RecordingsToUse))

# %%
#Use this for creating a dataset to compare to WN stimuli
RecordingsToUse = [r'D:\072624\J708LT',
                  r'D:\080224\J705RT',
                  r'D:\081024\J720LT']

# %%
#Use this for creating a dataset to compare to Fast Slow RC and SN stimuli


RecordingsToUse = [r'H:\101724\G6CK10JRT',
                   r'H:\102624\J722LT',
                   r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT',
                   r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2025\013125\G6CK14BLN',
                   r'\\goeppert\Vol2\Rolf\FreelyMovingEphys\2025\021225',
                   r'H:\111524\J715RT']

# %%
##Saline 
RecordingsToUse = [r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\052124\J691RT',
                   r'D:\080524\J705RT',
                   r'D:\080924\J720LT',
                   r'D:\081924\J716LT']

# %%
##Saline recordings that include sparse noise 
RecordingsToUse = [r'D:\080524\J705RT',
                   r'D:\080924\J720LT',
                   r'D:\081924\J716LT']

# %%
#Recordings to use for depth analysis

RecordingsToUse = [r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\091223\G6CK9GRT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\092223\G6CK9GTT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\110723\J683LT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\012324\G6CK11BTT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\022024\G6CK10DTT',
                  r'D:\072624\J708LT',
                  r'D:\080224\J705RT',
                  r'D:\081024\J720LT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT']

# %%
#Grating Dataset

RecordingsToUse = [r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2023\110723\J683LT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\012324\G6CK11BTT',
                  r'\\goeppert\Vol2\Rolf\Freely Moving Ephys\2024\022024\G6CK10DTT',
                  r'D:\072624\J708LT',
                  r'D:\080224\J705RT',
                  r'D:\081024\J720LT',
                  r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT',
                  r'\\goeppert\Vol2\Rolf\Freely Moving Ephys\2025\013125\G6CK14BLN',
                  r'\\goeppert\Vol2\Rolf\Freely Moving Ephys\2025\021225']

# %%
#Fast slow RC 
RecordingsToUse = [r'H:\101724\G6CK10JRT',
                   r'H:\102624\J722LT',
                   r'H:\111524\J715RT',
                   r'\\goeppert\nlab-nas\Rolf\Freely Moving Ephys\2024\122024\J728LT',
                   r'\\goeppert\Vol2\Rolf\Freely Moving Ephys\2025\013125\G6CK14BLN']

# %%
#Importing Important Stuff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as stat 
import math 
from pylab import *
import os
import fmEphys as fme

#import sys
#sys.path.append(r"\\goeppert\nlab-nas\Rolf\freely-moving-saccades")
#import saccadeAnalysis as sacc
# Out:
# Loading DLC 2.3.0...

# %%
def calc_std_modidx(psth,thresh):
 
    psth = psth.astype(float)
    psth = psth - np.nanmean(psth[100:750])

    std_thresh = np.nanstd(psth[100:750]*thresh)
    
    if np.nanmax((np.abs(psth[1000:1250])-std_thresh)) > 0:
        mod = 1
    else:
        mod = 0 
    return mod
    

def calc_fr_modidx(psth,thresh):

    psth = psth.astype(float)
    psth = psth - np.nanmean(psth[100:750])

    if np.nanmax(np.abs(psth[1000:1250])) > thresh:
        mod = 1
    else:
        mod = 0
    return mod

def calc_saccade_MM(psth):
    data = psth - np.nanmean(psth[100:750])
    data = data[1000:1250]
    latency = np.argmax(np.abs(data))
    MM = data[latency]
    return MM, latency

# %%
#Collecting Data Files for Analysis (Currently Just Collecting FM and Grating .h5 files)
dark_data = np.zeros(len(RecordingsToUse))
FM_Files = [[] for _ in range(len(RecordingsToUse))]
Dark_Files = [[] for _ in range(len(RecordingsToUse))]
Grating_Files = [[] for _ in range(len(RecordingsToUse))]

RC_Files = [[] for _ in range(len(RecordingsToUse))]
Single_Unit_Files = []
Grating_Mice =[[] for _ in range(len(RecordingsToUse))]
for ii in list(range(0,len(RecordingsToUse))):
    
    #Finding FM ephys files before DOI 
    RecordingPath = RecordingsToUse[ii]

    #Figuring out what type of recording it is based on the number of FM blocks
    FolderContent = os.listdir(RecordingPath)
    count = 0
    for zz in FolderContent:
        if zz.startswith("fm"):
            count = count + 1 
    print(count)

    # If 2 FM Blocks then FM1 is Pre DOI and FM2 is Post DOI
    if count == 2:
        
        PreFM_Path = RecordingPath + '/fm1'
        Items = os.listdir(PreFM_Path)
        for names in Items:
            if names.endswith("ephys_props.h5"):
                FM_Files[ii].append(PreFM_Path + '/' + names)
                
            
        #Finding FM ephys files after DOI         
        PostFM_Path = RecordingPath + '/fm2'           
        Items = os.listdir(PostFM_Path)
        for names in Items:
            if names.endswith("ephys_props.h5"):
                FM_Files[ii].append(PostFM_Path + '/' + names)
    
    # If 4 FM Blocks then FM2 is Pre DOI and FM4 is Post DOI (FM1 and FM3 are dark recordings)
    if count == 4:
        dark_data[ii] = 1
        PreFM_Path = RecordingPath + '/fm2'
        Items = os.listdir(PreFM_Path)
        for names in Items:
            if names.endswith("ephys_props.h5"):
                FM_Files[ii].append(PreFM_Path + '/' + names)
                
        #Finding FM ephys files after DOI         
        PostFM_Path = RecordingPath + '/fm4'           
        Items = os.listdir(PostFM_Path)
        for names in Items:
            if names.endswith("ephys_props.h5"):
                FM_Files[ii].append(PostFM_Path + '/' + names)

        #Finding dark file before doi          
        PreFM_Dark_Path = RecordingPath + '/fm1_dark'
        Items = os.listdir(PreFM_Dark_Path)
        for names in Items:
            if names.endswith("ephys_props.h5"):
                Dark_Files[ii].append(PreFM_Dark_Path + '/' + names)
                
        #Finding dark file after doi       
        PostFM_Dark_Path = RecordingPath + '/fm3_dark'           
        Items = os.listdir(PostFM_Dark_Path)
        for names in Items:
            if names.endswith("ephys_props.h5"):
                Dark_Files[ii].append(PostFM_Dark_Path + '/' + names)

    if count == 3:
            
            PreFM_Path = RecordingPath + '/fm2'
            Items = os.listdir(PreFM_Path)
            for names in Items:
                if names.endswith("ephys_props.h5"):
                    FM_Files[ii].append(PreFM_Path + '/' + names)
                    
                
            #Finding FM ephys files after DOI         
            PostFM_Path = RecordingPath + '/fm2'           
            Items = os.listdir(PostFM_Path)
            for names in Items:
                if names.endswith("ephys_props.h5"):
                    FM_Files[ii].append(PostFM_Path + '/' + names)



    #Finding Single Unit .npy file for each recording

    #for Items in os.listdir(RecordingPath):
    #    if Items.endswith("SingleUnits_NoThresh.npy"):
    #       Single_Unit_Files.append(RecordingPath +'/' + Items)

    for Items in os.listdir(RecordingPath):
        if Items.endswith("SingleUnits.npy"):
            Single_Unit_Files.append(RecordingPath +'/' + Items)
# Out:
# 4
# 4
# 4
# 4

# %%
#Creating Master dataframe with recordings of interest

PreFM_Data = pd.DataFrame()
PostFM_Data = pd.DataFrame()

PreFM_Dark_Data = pd.DataFrame()
PostFM_Dark_Data = pd.DataFrame()


PreGrating_Data = pd.DataFrame()
PostGrating_Data = pd.DataFrame()

PreRC_Data = pd.DataFrame()
PostRC_Data = pd.DataFrame()

for ii in list(range(0,len(RecordingsToUse))):

    date = os.path.basename(os.path.dirname(RecordingsToUse[ii]))
    mouse = os.path.basename(RecordingsToUse[ii])
    DateAndMouse = date + '_' + mouse

    Single_Units = np.load(Single_Unit_Files[ii])
    print(len(Single_Units))


    PreFM_Data_temp = pd.read_hdf(FM_Files[ii][0])
    PreFM_Data_temp['Mouse'] = DateAndMouse
    PreFM_Data_temp = PreFM_Data_temp.loc[Single_Units]
    

    PostFM_Data_temp = pd.read_hdf(FM_Files[ii][1])
    PostFM_Data_temp['Mouse'] = DateAndMouse
    PostFM_Data_temp =PostFM_Data_temp.loc[Single_Units]

    PreFM_Data = pd.concat([PreFM_Data, PreFM_Data_temp])
    PostFM_Data = pd.concat([PostFM_Data, PostFM_Data_temp])

    if dark_data[ii] == 1:
        
        PreFM_Dark_Data_temp = pd.read_hdf(Dark_Files[ii][0])
        PreFM_Dark_Data_temp['Mouse'] = DateAndMouse
        PreFM_Dark_Data_temp = PreFM_Dark_Data_temp.loc[Single_Units]
        

        PostFM_Dark_Data_temp = pd.read_hdf(Dark_Files[ii][1])
        PostFM_Dark_Data_temp['Mouse'] = DateAndMouse
        PostFM_Dark_Data_temp =PostFM_Dark_Data_temp.loc[Single_Units]

        PreFM_Dark_Data = pd.concat([PreFM_Dark_Data, PreFM_Dark_Data_temp])
        PostFM_Dark_Data = pd.concat([PostFM_Dark_Data, PostFM_Dark_Data_temp])

 
PreFM_Data['spike_sort_idx'] =PreFM_Data.index
PreFM_Data = PreFM_Data.reset_index()
PostFM_Data['spike_sort_idx'] =PostFM_Data.index
PostFM_Data = PostFM_Data.reset_index()

PreFM_Dark_Data['spike_sort_idx'] =PreFM_Dark_Data.index
PreFM_Dark_Data = PreFM_Dark_Data.reset_index()
PostFM_Dark_Data['spike_sort_idx'] =PostFM_Dark_Data.index
PostFM_Dark_Data = PostFM_Dark_Data.reset_index()

print( )
print(len(PreFM_Data))
print('Done!')
# Out:
# 72
# 49
# 29
# 42
#
# 192
# Done!

# %%
data = []
data_comp = []

Cells = np.stack(PreFM_Data.loc[:,'index'])

#Kernel for filtering
kernel_size = 100
kernel = np.ones(kernel_size) / kernel_size

for ii in list(PreFM_Data.index):

    Mouse = PreFM_Data.loc[ii,'Mouse']

    #################################################################################################################
    #Lightly Filter Pre and Post Drug Gaze and Comp Responses
    #Pre_Left_Gaze_filt = np.convolve(PreFM_Data.loc[ii,'FmLt_gazeshift_leftPSTH'], kernel, mode='same')
    #Pre_Right_Gaze_filt = np.convolve(PreFM_Data.loc[ii,'FmLt_gazeshift_rightPSTH'], kernel, mode='same')
    #Pre_Left_Comp_filt = np.convolve(PreFM_Data.loc[ii,'FmLt_compensatory_leftPSTH'], kernel, mode='same')
    #Pre_Right_Comp_filt = np.convolve(PreFM_Data.loc[ii,'FmLt_compensatory_rightPSTH'], kernel, mode='same')

    #Post_Left_Gaze_filt= np.convolve(PostFM_Data.loc[ii,'FmLt_gazeshift_leftPSTH'], kernel, mode='same')
    #Post_Right_Gaze_filt = np.convolve(PostFM_Data.loc[ii,'FmLt_gazeshift_rightPSTH'], kernel, mode='same')
    #Post_Left_Comp_filt = np.convolve(PostFM_Data.loc[ii,'FmLt_compensatory_leftPSTH'], kernel, mode='same')
    #Post_Right_Comp_filt = np.convolve(PostFM_Data.loc[ii,'FmLt_compensatory_rightPSTH'], kernel, mode='same')

    Pre_Left_Gaze_raw = PreFM_Data.loc[ii,'FmLt_gazeshift_leftPSTH']
    Pre_Right_Gaze_raw = PreFM_Data.loc[ii,'FmLt_gazeshift_rightPSTH']
    Pre_Left_Comp_raw = PreFM_Data.loc[ii,'FmLt_compensatory_leftPSTH']
    Pre_Right_Comp_raw = PreFM_Data.loc[ii,'FmLt_compensatory_rightPSTH']

    Post_Left_Gaze_raw= PostFM_Data.loc[ii,'FmLt_gazeshift_leftPSTH']
    Post_Right_Gaze_raw = PostFM_Data.loc[ii,'FmLt_gazeshift_rightPSTH']
    Post_Left_Comp_raw = PostFM_Data.loc[ii,'FmLt_compensatory_leftPSTH']
    Post_Right_Comp_raw = PostFM_Data.loc[ii,'FmLt_compensatory_rightPSTH']

    
    #################################################################################################################
    #Subtracting off baseline
    Pre_Left_Gaze_bs = Pre_Left_Gaze_raw - np.nanmean(Pre_Left_Gaze_raw[100:750])
    Pre_Right_Gaze_bs = Pre_Right_Gaze_raw - np.nanmean(Pre_Right_Gaze_raw[100:750])
    Pre_Left_Comp_bs = Pre_Left_Comp_raw - np.nanmean(Pre_Left_Comp_raw[100:750])
    Pre_Right_Comp_bs = Pre_Right_Comp_raw - np.nanmean(Pre_Right_Comp_raw[100:750])

    Post_Left_Gaze_bs = Post_Left_Gaze_raw - np.nanmean(Post_Left_Gaze_raw[100:750])
    Post_Right_Gaze_bs = Post_Right_Gaze_raw - np.nanmean(Post_Right_Gaze_raw[100:750])
    Post_Left_Comp_bs = Post_Left_Comp_raw - np.nanmean(Post_Left_Comp_raw[100:750])
    Post_Right_Comp_bs = Post_Right_Comp_raw - np.nanmean(Post_Right_Comp_raw[100:750])

    #################################################################################################################
    #Calculating Max Modulations 
    Pre_Left_Gaze_MM = calc_saccade_MM(Pre_Left_Gaze_raw)[0]
    Pre_Right_Gaze_MM = calc_saccade_MM(Pre_Right_Gaze_raw)[0]
    
    Post_Left_Gaze_MM = calc_saccade_MM(Post_Left_Gaze_raw)[0]  
    Post_Right_Gaze_MM = calc_saccade_MM(Post_Right_Gaze_raw)[0]  

    #################################################################################################################
    #Calculating Preferred Gaze and Comp Response Pre and Post Drug
    Pre_Gaze_DS = ((np.nanmax(np.abs(Pre_Left_Gaze_bs[750:1500]))) - (np.nanmax(np.abs(Pre_Right_Gaze_bs[750:1500])))) / ((np.nanmax(np.abs(Pre_Left_Gaze_bs[750:1500]))) + (np.nanmax(np.abs(Pre_Right_Gaze_bs[750:1500]))))
    Post_Gaze_DS = ((np.nanmax(np.abs(Post_Left_Gaze_bs[750:1500]))) - (np.nanmax(np.abs(Post_Right_Gaze_bs[750:1500])))) / ((np.nanmax(np.abs(Post_Left_Gaze_bs[750:1500]))) + (np.nanmax(np.abs(Post_Right_Gaze_bs[750:1500]))))

    Pre_Comp_DS = ((np.nanmax(np.abs(Pre_Left_Comp_bs[750:1500]))) - (np.nanmax(np.abs(Pre_Right_Comp_bs[750:1500])))) / ((np.nanmax(np.abs(Pre_Left_Comp_bs[750:1500]))) + (np.nanmax(np.abs(Pre_Right_Comp_bs[750:1500]))))
    Post_Comp_DS = ((np.nanmax(np.abs(Post_Left_Comp_bs[750:1500]))) - (np.nanmax(np.abs(Post_Right_Comp_bs[750:1500])))) / ((np.nanmax(np.abs(Post_Left_Comp_bs[750:1500]))) + (np.nanmax(np.abs(Post_Right_Comp_bs[750:1500]))))


    ################################################################################################################
    #Finding Preferred and Non Pref Pre Drug Gaze
    if Pre_Gaze_DS > 0:
        Pref_Gaze_Pre_Raw = PreFM_Data.loc[ii,'FmLt_gazeshift_leftPSTH']
        Pref_Gaze_Pre = Pre_Left_Gaze_bs
        Pref_GazeTimes_Pre = PreFM_Data.loc[ii,'FmLt_gazeshift_leftT']

        NonPref_Gaze_Pre_Raw = PreFM_Data.loc[ii,'FmLt_gazeshift_rightPSTH']
        NonPref_GazeTimes_Pre = PreFM_Data.loc[ii,'FmLt_gazeshift_rightT']
    else:
        Pref_Gaze_Pre_Raw = PreFM_Data.loc[ii,'FmLt_gazeshift_rightPSTH']
        Pref_Gaze_Pre = Pre_Right_Gaze_bs
        Pref_GazeTimes_Pre = PreFM_Data.loc[ii,'FmLt_gazeshift_rightT']

        NonPref_Gaze_Pre_Raw = PreFM_Data.loc[ii,'FmLt_gazeshift_leftPSTH']
        NonPref_GazeTimes_Pre = PreFM_Data.loc[ii,'FmLt_gazeshift_leftT']
        
    #Finding Preferred and Non Pref Post Drug Gaze
    if Pre_Gaze_DS  > 0:
        Pref_Gaze_Post_Raw = PostFM_Data.loc[ii,'FmLt_gazeshift_leftPSTH']
        Pref_Gaze_Post = Post_Left_Gaze_bs
        Pref_GazeTimes_Post = PostFM_Data.loc[ii,'FmLt_gazeshift_leftT']

        NonPref_Gaze_Post_Raw = PostFM_Data.loc[ii,'FmLt_gazeshift_rightPSTH']
        NonPref_GazeTimes_Post = PostFM_Data.loc[ii,'FmLt_gazeshift_rightT']
    else:
        Pref_Gaze_Post_Raw = PostFM_Data.loc[ii,'FmLt_gazeshift_rightPSTH']
        Pref_Gaze_Post = Post_Right_Gaze_bs  
        Pref_GazeTimes_Post = PostFM_Data.loc[ii,'FmLt_gazeshift_rightT']
        
        NonPref_Gaze_Post_Raw = PostFM_Data.loc[ii,'FmLt_gazeshift_leftPSTH']
        NonPref_GazeTimes_Post = PostFM_Data.loc[ii,'FmLt_gazeshift_leftT']

    #################################################################################################################
    #Normalizing Pref Gaze Responses and applying thresholds to 
    #Pref_Gaze_Pre_Norm_4Clust = Pref_Gaze_Pre/np.abs(Pref_Gaze_Pre_MM)
    #Pref_Gaze_Post_Norm_4Clust = Pref_Gaze_Post/np.abs(Pref_Gaze_Post_MM)

    Pre_STD_Thresh = calc_std_modidx(Pref_Gaze_Pre,3.5)
    Pre_FR_Thresh = calc_fr_modidx(Pref_Gaze_Pre_Raw,1)

    Pre_Responsive = 1
    if (Pre_STD_Thresh == 0) or (Pre_FR_Thresh == 0):
      #  Pref_Gaze_Pre_Norm_4Clust[:] = 0
        Pre_Responsive = 0

    Post_STD_Thresh = calc_std_modidx(Pref_Gaze_Post,3.5)
    Post_FR_Thresh = calc_fr_modidx(Pref_Gaze_Post_Raw,1)

    Post_Responsive = 1
    if (Post_STD_Thresh == 0) or (Post_FR_Thresh == 0):
       # Pref_Gaze_Post_Norm_4Clust[:] = 0
        Post_Responsive = 0

    #################################################################################################################
    #Finding Preferred and Non Pref Pre Drug Comp
    if Pre_Comp_DS > 0:
        Pref_Comp_Pre_Raw = PreFM_Data.loc[ii,'FmLt_compensatory_leftPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        Pref_CompTimes_Pre = PreFM_Data.loc[ii,'FmLt_compensatory_leftT']
        NonPref_Comp_Pre_Raw = PreFM_Data.loc[ii,'FmLt_compensatory_rightPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        NonPref_CompTimes_Pre = PreFM_Data.loc[ii,'FmLt_compensatory_rightT']
    else:
        Pref_Comp_Pre_Raw = PreFM_Data.loc[ii,'FmLt_compensatory_rightPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        Pref_CompTimes_Pre = PreFM_Data.loc[ii,'FmLt_compensatory_rightT']
        NonPref_Comp_Pre_Raw = PreFM_Data.loc[ii,'FmLt_compensatory_leftPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        NonPref_CompTimes_Pre = PreFM_Data.loc[ii,'FmLt_compensatory_leftT']

    #Finding Preferred and Non Pref Post Drug Comp
    if Post_Comp_DS > 0:
        Pref_Comp_Post_Raw = PostFM_Data.loc[ii,'FmLt_compensatory_leftPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        Pref_CompTimes_Post = PostFM_Data.loc[ii,'FmLt_compensatory_leftT']
        NonPref_Comp_Post_Raw = PostFM_Data.loc[ii,'FmLt_compensatory_rightPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        NonPref_CompTimes_Post = PostFM_Data.loc[ii,'FmLt_compensatory_rightT']
    else:
        Pref_Comp_Post_Raw = PostFM_Data.loc[ii,'FmLt_compensatory_rightPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        Pref_CompTimes_Post = PostFM_Data.loc[ii,'FmLt_compensatory_rightT']
        NonPref_Comp_Post_Raw = PostFM_Data.loc[ii,'FmLt_compensatory_leftPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        NonPref_CompTimes_Post = PostFM_Data.loc[ii,'FmLt_compensatory_leftT']

    #################################################################################################################

    data.append({'Mouse': Mouse,
                 'Cell': Cells[ii],
                 'Contamination_Index': PreFM_Data.loc[ii,'FmLt_ContamPct'],

                 'Pre_Responsive': Pre_Responsive,
                 'Post_Responsive': Post_Responsive,

                 'Pre_Gaze_DS': Pre_Gaze_DS,
                 'Post_Gaze_DS': Post_Gaze_DS,

                 'Pre_Left_Gaze': Pre_Left_Gaze_raw,
                 'Pre_Right_Gaze': Pre_Right_Gaze_raw,
                 'Post_Left_Gaze': Post_Left_Gaze_raw,
                 'Post_Right_Gaze': Post_Right_Gaze_raw,

                 'Pre_Pref_Gaze': Pref_Gaze_Pre_Raw,
                 'Post_Pref_Gaze': Pref_Gaze_Post_Raw,
                 'Pre_NonPref_Gaze': NonPref_Gaze_Pre_Raw,
                 'Post_NonPref_Gaze': NonPref_Gaze_Post_Raw,

                 'Pre_Pref_Gaze_Times': Pref_GazeTimes_Pre,
                 'Post_Pref_Gaze_Times': Pref_GazeTimes_Post,
                 'Pre_NonPref_Gaze_Times': NonPref_GazeTimes_Pre,
                 'Post_NonPref_Gaze_Times': NonPref_GazeTimes_Post,
                 
                 'Pre_SpikeT': PreFM_Data.loc[ii,'FmLt_spikeT'],
                 'Post_SpikeT': PostFM_Data.loc[ii,'FmLt_spikeT']
                 })




    data_comp.append({'Mouse': Mouse,
                      'Cell': Cells[ii],
                      'Contamination_Index': PreFM_Data.loc[ii,'FmLt_ContamPct'],

                      'Pre_Comp_DS': Pre_Comp_DS,
                      'Post_Comp_DS': Post_Comp_DS,

                      'Pre_Left_Comp': Pre_Left_Comp_raw,
                      'Pre_Right_Comp': Pre_Right_Comp_raw,
                      'Post_Left_Comp': Post_Left_Comp_raw,
                      'Post_Right_Comp': Post_Right_Comp_raw,


                      'Pre_Pref_Comp': Pref_Comp_Pre_Raw,
                      'Post_Pref_Comp': Pref_Comp_Post_Raw,
                      'Pre_NonPref_Comp': NonPref_Comp_Pre_Raw,
                      'Post_NonPref_Comp': NonPref_Comp_Post_Raw,
                      
                      'Pre_Pref_Comp_Times': Pref_CompTimes_Pre,
                      'Post_Pref_Comp_Times': Pref_CompTimes_Post,
                      'Pre_NonPref_Comp_Times': Pref_CompTimes_Pre,
                      'Post_NonPref_Comp_Times': Pref_CompTimes_Post,
                                      
                      'Pre_SpikeT': PreFM_Data.loc[ii,'FmLt_spikeT'],
                      'Post_SpikeT': PostFM_Data.loc[ii,'FmLt_spikeT']
                      })

df = pd.DataFrame(data)    
df_comp = pd.DataFrame(data_comp)

# %%
data = []
data_comp = []

Cells = np.stack(PreFM_Dark_Data.loc[:,'index'])

#Kernel for fiDkering
kernel_size = 100
kernel = np.ones(kernel_size) / kernel_size

for ii in list(PreFM_Dark_Data.index):

    Mouse = PreFM_Dark_Data.loc[ii,'Mouse']

    #################################################################################################################
    #Lightly FiDker Pre and Post Drug Gaze and Comp Responses
    #Pre_Left_Gaze_fiDk = np.convolve(PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftPSTH'], kernel, mode='same')
    #Pre_Right_Gaze_fiDk = np.convolve(PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightPSTH'], kernel, mode='same')
    #Pre_Left_Comp_fiDk = np.convolve(PreFM_Dark_Data.loc[ii,'FmDk_compensatory_leftPSTH'], kernel, mode='same')
    #Pre_Right_Comp_fiDk = np.convolve(PreFM_Dark_Data.loc[ii,'FmDk_compensatory_rightPSTH'], kernel, mode='same')

    #Post_Left_Gaze_fiDk= np.convolve(PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftPSTH'], kernel, mode='same')
    #Post_Right_Gaze_fiDk = np.convolve(PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightPSTH'], kernel, mode='same')
    #Post_Left_Comp_fiDk = np.convolve(PostFM_Dark_Data.loc[ii,'FmDk_compensatory_leftPSTH'], kernel, mode='same')
    #Post_Right_Comp_fiDk = np.convolve(PostFM_Dark_Data.loc[ii,'FmDk_compensatory_rightPSTH'], kernel, mode='same')

    Pre_Left_Gaze_raw = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftPSTH']
    Pre_Right_Gaze_raw = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightPSTH']
    Pre_Left_Comp_raw = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_leftPSTH']
    Pre_Right_Comp_raw = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_rightPSTH']

    Post_Left_Gaze_raw= PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftPSTH']
    Post_Right_Gaze_raw = PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightPSTH']
    Post_Left_Comp_raw = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_leftPSTH']
    Post_Right_Comp_raw = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_rightPSTH']

    
    #################################################################################################################
    #Subtracting off baseline
    Pre_Left_Gaze_bs = Pre_Left_Gaze_raw - np.nanmean(Pre_Left_Gaze_raw[100:750])
    Pre_Right_Gaze_bs = Pre_Right_Gaze_raw - np.nanmean(Pre_Right_Gaze_raw[100:750])
    Pre_Left_Comp_bs = Pre_Left_Comp_raw - np.nanmean(Pre_Left_Comp_raw[100:750])
    Pre_Right_Comp_bs = Pre_Right_Comp_raw - np.nanmean(Pre_Right_Comp_raw[100:750])

    Post_Left_Gaze_bs = Post_Left_Gaze_raw - np.nanmean(Post_Left_Gaze_raw[100:750])
    Post_Right_Gaze_bs = Post_Right_Gaze_raw - np.nanmean(Post_Right_Gaze_raw[100:750])
    Post_Left_Comp_bs = Post_Left_Comp_raw - np.nanmean(Post_Left_Comp_raw[100:750])
    Post_Right_Comp_bs = Post_Right_Comp_raw - np.nanmean(Post_Right_Comp_raw[100:750])

    #################################################################################################################
    #Calculating Max Modulations 
    Pre_Left_Gaze_MM = calc_saccade_MM(Pre_Left_Gaze_raw)[0]
    Pre_Right_Gaze_MM = calc_saccade_MM(Pre_Right_Gaze_raw)[0]
    
    Post_Left_Gaze_MM = calc_saccade_MM(Post_Left_Gaze_raw)[0]  
    Post_Right_Gaze_MM = calc_saccade_MM(Post_Right_Gaze_raw)[0]  

    #################################################################################################################
    #Calculating Preferred Gaze and Comp Response Pre and Post Drug
    Pre_Gaze_DS = ((np.nanmax(np.abs(Pre_Left_Gaze_bs[750:1500]))) - (np.nanmax(np.abs(Pre_Right_Gaze_bs[750:1500])))) / ((np.nanmax(np.abs(Pre_Left_Gaze_bs[750:1500]))) + (np.nanmax(np.abs(Pre_Right_Gaze_bs[750:1500]))))
    Post_Gaze_DS = ((np.nanmax(np.abs(Post_Left_Gaze_bs[750:1500]))) - (np.nanmax(np.abs(Post_Right_Gaze_bs[750:1500])))) / ((np.nanmax(np.abs(Post_Left_Gaze_bs[750:1500]))) + (np.nanmax(np.abs(Post_Right_Gaze_bs[750:1500]))))

    Pre_Comp_DS = ((np.nanmax(np.abs(Pre_Left_Comp_bs[750:1500]))) - (np.nanmax(np.abs(Pre_Right_Comp_bs[750:1500])))) / ((np.nanmax(np.abs(Pre_Left_Comp_bs[750:1500]))) + (np.nanmax(np.abs(Pre_Right_Comp_bs[750:1500]))))
    Post_Comp_DS = ((np.nanmax(np.abs(Post_Left_Comp_bs[750:1500]))) - (np.nanmax(np.abs(Post_Right_Comp_bs[750:1500])))) / ((np.nanmax(np.abs(Post_Left_Comp_bs[750:1500]))) + (np.nanmax(np.abs(Post_Right_Comp_bs[750:1500]))))


    ################################################################################################################
    #Finding Preferred and Non Pref Pre Drug Gaze
    if Pre_Gaze_DS > 0:
        Pref_Gaze_Pre_Raw = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftPSTH']
        Pref_Gaze_Pre = Pre_Left_Gaze_bs
        Pref_GazeTimes_Pre = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftT']

        NonPref_Gaze_Pre_Raw = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightPSTH']
        NonPref_GazeTimes_Pre = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightT']
    else:
        Pref_Gaze_Pre_Raw = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightPSTH']
        Pref_Gaze_Pre = Pre_Right_Gaze_bs
        Pref_GazeTimes_Pre = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightT']

        NonPref_Gaze_Pre_Raw = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftPSTH']
        NonPref_GazeTimes_Pre = PreFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftT']
        
    #Finding Preferred and Non Pref Post Drug Gaze
    if Pre_Gaze_DS  > 0:
        Pref_Gaze_Post_Raw = PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftPSTH']
        Pref_Gaze_Post = Post_Left_Gaze_bs
        Pref_GazeTimes_Post = PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftT']

        NonPref_Gaze_Post_Raw = PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightPSTH']
        NonPref_GazeTimes_Post = PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightT']
    else:
        Pref_Gaze_Post_Raw = PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightPSTH']
        Pref_Gaze_Post = Post_Right_Gaze_bs  
        Pref_GazeTimes_Post = PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_rightT']
        
        NonPref_Gaze_Post_Raw = PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftPSTH']
        NonPref_GazeTimes_Post = PostFM_Dark_Data.loc[ii,'FmDk_gazeshift_leftT']

    #################################################################################################################
    #Normalizing Pref Gaze Responses and applying thresholds to 
    #Pref_Gaze_Pre_Norm_4Clust = Pref_Gaze_Pre/np.abs(Pref_Gaze_Pre_MM)
    #Pref_Gaze_Post_Norm_4Clust = Pref_Gaze_Post/np.abs(Pref_Gaze_Post_MM)

    Pre_STD_Thresh = calc_std_modidx(Pref_Gaze_Pre,3.5)
    Pre_FR_Thresh = calc_fr_modidx(Pref_Gaze_Pre_Raw,1)

    Pre_Responsive = 1
    if (Pre_STD_Thresh == 0) or (Pre_FR_Thresh == 0):
      #  Pref_Gaze_Pre_Norm_4Clust[:] = 0
        Pre_Responsive = 0

    Post_STD_Thresh = calc_std_modidx(Pref_Gaze_Post,3.5)
    Post_FR_Thresh = calc_fr_modidx(Pref_Gaze_Post_Raw,1)

    Post_Responsive = 1
    if (Post_STD_Thresh == 0) or (Post_FR_Thresh == 0):
       # Pref_Gaze_Post_Norm_4Clust[:] = 0
        Post_Responsive = 0

    #################################################################################################################
    #Finding Preferred and Non Pref Pre Drug Comp
    if Pre_Comp_DS > 0:
        Pref_Comp_Pre_Raw = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_leftPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        Pref_CompTimes_Pre = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_leftT']
        NonPref_Comp_Pre_Raw = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_rightPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        NonPref_CompTimes_Pre = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_rightT']
    else:
        Pref_Comp_Pre_Raw = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_rightPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        Pref_CompTimes_Pre = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_rightT']
        NonPref_Comp_Pre_Raw = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_leftPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        NonPref_CompTimes_Pre = PreFM_Dark_Data.loc[ii,'FmDk_compensatory_leftT']

    #Finding Preferred and Non Pref Post Drug Comp
    if Post_Comp_DS > 0:
        Pref_Comp_Post_Raw = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_leftPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        Pref_CompTimes_Post = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_leftT']
        NonPref_Comp_Post_Raw = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_rightPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        NonPref_CompTimes_Post = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_rightT']
    else:
        Pref_Comp_Post_Raw = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_rightPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        Pref_CompTimes_Post = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_rightT']
        NonPref_Comp_Post_Raw = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_leftPSTH']
        #Pref_Comp_Pre = Pre_Left_Comp
        NonPref_CompTimes_Post = PostFM_Dark_Data.loc[ii,'FmDk_compensatory_leftT']

    #################################################################################################################

    data.append({'Mouse': Mouse,
                 'Cell': Cells[ii],
                 'Contamination_Index': PostFM_Dark_Data.loc[ii,'FmDk_ContamPct'],

                 'Pre_Responsive': Pre_Responsive,
                 'Post_Responsive': Post_Responsive,

                 'Pre_Gaze_DS': Pre_Gaze_DS,
                 'Post_Gaze_DS': Post_Gaze_DS,

                 'Pre_Left_Gaze': Pre_Left_Gaze_raw,
                 'Pre_Right_Gaze': Pre_Right_Gaze_raw,
                 'Post_Left_Gaze': Post_Left_Gaze_raw,
                 'Post_Right_Gaze': Post_Right_Gaze_raw,

                 'Pre_Pref_Gaze': Pref_Gaze_Pre_Raw,
                 'Post_Pref_Gaze': Pref_Gaze_Post_Raw,
                 'Pre_NonPref_Gaze': NonPref_Gaze_Pre_Raw,
                 'Post_NonPref_Gaze': NonPref_Gaze_Post_Raw,

                 'Pre_Pref_Gaze_Times': Pref_GazeTimes_Pre,
                 'Post_Pref_Gaze_Times': Pref_GazeTimes_Post,
                 'Pre_NonPref_Gaze_Times': NonPref_GazeTimes_Pre,
                 'Post_NonPref_Gaze_Times': NonPref_GazeTimes_Post,
                 
                 'Pre_SpikeT': PreFM_Dark_Data.loc[ii,'FmDk_spikeT'],
                 'Post_SpikeT': PostFM_Dark_Data.loc[ii,'FmDk_spikeT']
                 })




    data_comp.append({'Mouse': Mouse,
                      'Cell': Cells[ii],
                      'Contamination_Index': PostFM_Dark_Data.loc[ii,'FmDk_ContamPct'],

                      'Pre_Comp_DS': Pre_Comp_DS,
                      'Post_Comp_DS': Post_Comp_DS,

                      'Pre_Left_Comp': Pre_Left_Comp_raw,
                      'Pre_Right_Comp': Pre_Right_Comp_raw,
                      'Post_Left_Comp': Post_Left_Comp_raw,
                      'Post_Right_Comp': Post_Right_Comp_raw,


                      'Pre_Pref_Comp': Pref_Comp_Pre_Raw,
                      'Post_Pref_Comp': Pref_Comp_Post_Raw,
                      'Pre_NonPref_Comp': NonPref_Comp_Pre_Raw,
                      'Post_NonPref_Comp': NonPref_Comp_Post_Raw,
                      
                      'Pre_Pref_Comp_Times': Pref_CompTimes_Pre,
                      'Post_Pref_Comp_Times': Pref_CompTimes_Post,
                      'Pre_NonPref_Comp_Times': Pref_CompTimes_Pre,
                      'Post_NonPref_Comp_Times': Pref_CompTimes_Post,
                                      
                      'Pre_SpikeT': PreFM_Dark_Data.loc[ii,'FmDk_spikeT'],
                      'Post_SpikeT': PostFM_Dark_Data.loc[ii,'FmDk_spikeT']
                      })

df_dark = pd.DataFrame(data)    
df_comp_dark = pd.DataFrame(data_comp)

# %%
#Change the file names below depending on the dataset/mice uesd

df.to_hdf(os.path.join(os.path.join('D:\PrePostDOI\DOI Datasets','LD_Mice_Light_GazeShifts_DOI.h5')), 'w')
df_comp.to_hdf(os.path.join(os.path.join('D:\PrePostDOI\DOI Datasets','LD_Mice_Light_Compensatory_DOI.h5')), 'w')

df_dark.to_hdf(os.path.join(os.path.join('D:\PrePostDOI\DOI Datasets','LD_Mice_Dark_GazeShifts_DOI.h5')), 'w')
df_comp_dark.to_hdf(os.path.join(os.path.join('D:\PrePostDOI\DOI Datasets','LD_Mice_Dark_Compensatory_DOI.h5')), 'w')

#df.to_hdf(os.path.join(os.path.join('D:\PrePostDOI\Saline Datasets','SNandWNMice_GazeShifts_Saline.h5')), 'w')
#df_comp.to_hdf(os.path.join(os.path.join('D:\PrePostDOI\Saline Datasets','SNandWNMice_Compensatory_Saline.h5')), 'w')
